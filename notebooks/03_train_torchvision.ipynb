# %%
import sys
from pathlib import Path

p = Path.cwd()
while p != p.parent and not (p / "src").exists():
    p = p.parent

REPO = p
SRC = REPO / "src"
sys.path.insert(0, str(SRC))

print("Using REPO:", REPO)
print("SRC exists:", SRC.exists(), SRC)
# Out:
# Using REPO: /Users/oliwiaw/Desktop/python/WMUM
# SRC exists: True /Users/oliwiaw/Desktop/python/WMUM/src

# %%
import train_torchvision
train_torchvision.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import train_torchvision
#       2 train_torchvision.main()
#
# File ~/Desktop/python/WMUM/src/train_torchvision.py:8
#       5 import json
#       6 from typing import List, Dict, Tuple
# ----> 8 import torch
#       9 from torch.utils.data import DataLoader
#      10 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'torch'
