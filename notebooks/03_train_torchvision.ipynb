# %%
import sys
from pathlib import Path

p = Path.cwd()
while p != p.parent and not (p / "src").exists():
    p = p.parent

REPO = p
SRC = REPO / "src"
sys.path.insert(0, str(SRC))

print("Using REPO:", REPO)
print("SRC exists:", SRC.exists(), SRC)

# %load_ext autoreload
# %autoreload 2
# Out:
# Using REPO: /Users/oliwiaw/PycharmProjects/WMUM
# SRC exists: True /Users/oliwiaw/PycharmProjects/WMUM/src

# %%
import train_torchvision
import train_torchvision_gray

# print("=== Torchvision RGB training ===")
# train_torchvision.main()

print("=== Torchvision GRAY training ===")
train_torchvision_gray.main()
# Out:
# === Torchvision GRAY training ===
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# cats_dogs__fasterrcnn__gray epoch 1/10 loss=0.4749
# cats_dogs__fasterrcnn__gray epoch 2/10 loss=0.1911
# cats_dogs__fasterrcnn__gray epoch 3/10 loss=0.1858
# cats_dogs__fasterrcnn__gray epoch 4/10 loss=0.2885
# cats_dogs__fasterrcnn__gray epoch 5/10 loss=0.1498
# cats_dogs__fasterrcnn__gray epoch 6/10 loss=0.1387
# cats_dogs__fasterrcnn__gray epoch 7/10 loss=0.1227
# cats_dogs__fasterrcnn__gray epoch 8/10 loss=0.1450
# cats_dogs__fasterrcnn__gray epoch 9/10 loss=0.3341
# cats_dogs__fasterrcnn__gray epoch 10/10 loss=0.1603
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# ...
