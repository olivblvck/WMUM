# %%
import sys
from pathlib import Path

p = Path.cwd()
while p != p.parent and not (p / "src").exists():
    p = p.parent

REPO = p
SRC = REPO / "src"
sys.path.insert(0, str(SRC))

print("Using REPO:", REPO)
print("SRC exists:", SRC.exists(), SRC)

# %load_ext autoreload
# %autoreload 2
# Out:
# Using REPO: /Users/oliwiaw/PycharmProjects/WMUM
# SRC exists: True /Users/oliwiaw/PycharmProjects/WMUM/src

# %%
import train_ultralytics
train_ultralytics.main()
# Out:
# [SKIP] cats_dogs__yolov8n best exists: /Users/oliwiaw/PycharmProjects/WMUM/runs/ultralytics/cats_dogs__yolov8n/weights/best.pt
# Ultralytics 8.4.6 🚀 Python-3.13.2 torch-2.10.0 CPU (Apple M2)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 162.5±36.4 MB/s, size: 44.5 KB)
# val: Scanning /Users/oliwiaw/PycharmProjects/WMUM/data/processed/yolov8/cats_dogs/valid/labels.cache... 132 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 132/132 7.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.1s/it 10.2s1.3s
#                    all        132        218      0.693      0.682      0.717      0.509
#                    Cat         65        114       0.76      0.719      0.723      0.536
#                    Dog         68        104      0.626      0.644      0.711      0.483
# ...
