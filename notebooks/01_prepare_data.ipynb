# %%
import sys
from pathlib import Path

p = Path.cwd()
while p != p.parent and not (p / "src").exists():
    p = p.parent

REPO = p
SRC = REPO / "src"
sys.path.insert(0, str(SRC))

print("Using REPO:", REPO)
print("SRC exists:", SRC.exists(), SRC)
# Out:
# Using REPO: /Users/oliwiaw/Desktop/python/WMUM
# SRC exists: True /Users/oliwiaw/Desktop/python/WMUM/src

# %%
import prepare_data
prepare_data.main()
# Out:
# Done. Reports in: /Users/oliwiaw/Desktop/python/WMUM/data/processed/_reports
# - cats_dogs [yolov8] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - cats_dogs [coco] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - fruits_vegetables [yolov8] removed_boxes=3 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - fruits_vegetables [coco] removed_boxes=0 clipped_boxes=49 coco_images_removed=0 coco_ann_removed=0
# - traffic_signs [yolov8] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - traffic_signs [coco] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - vehicles [yolov8] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - vehicles [coco] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - people [yolov8] removed_boxes=0 clipped_boxes=0 coco_images_removed=0 coco_ann_removed=0
# - people [coco] removed_boxes=0 clipped_boxes=485 coco_images_removed=0 coco_ann_removed=0
